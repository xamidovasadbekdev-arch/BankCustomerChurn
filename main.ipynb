# %% [markdown]
# # Data Loading and Understanding

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Customer-Churn-Records.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
# 3         93826.63       0         0                   5      GOLD
# 4         79084.10       0         0                   5      GOLD
#
#    Point Earned
# 0           464
# 1           456
# 2           377
# 3           350
# 4           425

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 9995         96270.64       0         0                   1   DIAMOND
# 9996        101699.77       0         0                   5  PLATINUM
# 9997         42085.58       1         1                   3    SILVER
# 9998         92888.52       1         1                   2      GOLD
# 9999         38190.78       0         0                   3   DIAMOND
#
#       Point Earned
# 9995           300
# 9996           771
# 9997           564
# 9998           339
# 9999           911

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
#  15  Satisfaction Score  10000 non-null  int64
#  16  Card Type           10000 non-null  object
#  17  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited      Complain  Satisfaction Score  \
# count     10000.000000  10000.000000  10000.000000        10000.000000
# mean     100090.239881      0.203800      0.204400            3.013800
# std       57510.492818      0.402842      0.403283            1.405919
# min          11.580000      0.000000      0.000000            1.000000
# 25%       51002.110000      0.000000      0.000000            2.000000
# 50%      100193.915000      0.000000      0.000000            3.000000
# 75%      149388.247500      0.000000      0.000000            4.000000
# max      199992.480000      1.000000      1.000000            5.000000
#
#        Point Earned
# count  10000.000000
# mean     606.515100
# std      225.924839
# min      119.000000
# 25%      410.000000
# 50%      605.000000
# 75%      801.000000
# max     1000.000000

# %% [markdown]
# # Data Cleaning

# %%
df.sample(3)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 437         438    15624623       Hs?          516    France    Male   35
# 1229       1230    15607598  Muravyov          575     Spain  Female   31
# 144         145    15612350    Taylor          691    France  Female   31
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 437       10  104088.59              2          0               0
# 1229       6       0.00              2          1               1
# 144        5   40915.55              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 437         119666.00       0         0                   1      GOLD
# 1229         95686.42       0         0                   4    SILVER
# 144         126213.84       1         0                   2    SILVER
#
#       Point Earned
# 437            565
# 1229           609
# 144            402

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# RowNumber             0
# CustomerId            0
# Card Type             0
# Satisfaction Score    0
# Complain              0
# Exited                0
# EstimatedSalary       0
# IsActiveMember        0
# HasCrCard             0
# NumOfProducts         0
# dtype: int64

# %%
miss = ((df.isna().sum()/len(df))*100).round(2)
miss[miss>0].sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %%
sns.heatmap(df.isnull(), cbar=False, cmap="Reds")
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(3)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 7150       7151    15691150          Ku          699    France  Female   32
# 5838       5839    15570379  Whitelegge          669     Spain    Male   51
# 282         283    15643024       Huang          479   Germany    Male   35
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7150       4  110559.46              1          1               1
# 5838       3   88827.53              1          0               0
# 282        4  138718.92              1          1               1
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 7150        127429.56       0         0                   2    SILVER
# 5838         85250.77       1         1                   3   DIAMOND
# 282          47251.79       1         1                   1      GOLD
#
#       Point Earned
# 7150           713
# 5838           612
# 282            751

# %%
df.Exited.value_counts()
# Out:
# Exited
# 0    7962
# 1    2038
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited      Complain  Satisfaction Score  \
# count     10000.000000  10000.000000  10000.000000        10000.000000
# mean     100090.239881      0.203800      0.204400            3.013800
# std       57510.492818      0.402842      0.403283            1.405919
# min          11.580000      0.000000      0.000000            1.000000
# 25%       51002.110000      0.000000      0.000000            2.000000
# 50%      100193.915000      0.000000      0.000000            3.000000
# 75%      149388.247500      0.000000      0.000000            4.000000
# max      199992.480000      1.000000      1.000000            5.000000
#
#        Point Earned
# count  10000.000000
# mean     606.515100
# std      225.924839
# min      119.000000
# 25%      410.000000
# 50%      605.000000
# 75%      801.000000
# max     1000.000000

# %% [markdown]
# # EDA

# %%
df.sample(3)
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 1334       1335    15664772  Greece          489   Germany    Male   28
# 8485       8486    15724269     Yao          670    France    Male   25
# 5992       5993    15682955   Capon          758    France  Female   32
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1334       1  79460.98              2          1               1
# 8485       7      0.00              2          1               1
# 5992       2  84378.90              1          1               1
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 1334        167973.63       0         0                   3  PLATINUM
# 8485        144723.38       0         0                   2      GOLD
# 5992         75396.43       0         0                   3  PLATINUM
#
#       Point Earned
# 1334           232
# 8485           940
# 5992           867

# %%
sns.barplot(x="Geography", y="Exited", data=df)

plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(x="Geography", data=df)
# Out:
# <Axes: xlabel='Geography', ylabel='Count'>

# %%
df.groupby("Geography")["Exited"].mean()
# Out:
# Geography
# France     0.161747
# Germany    0.324432
# Spain      0.166734
# Name: Exited, dtype: float64

# %%
df.groupby("Geography")["Exited"].agg(["mean", "sum", "count"])
# Out:
#                mean  sum  count
# Geography
# France     0.161747  811   5014
# Germany    0.324432  814   2509
# Spain      0.166734  413   2477

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
#
#    Point Earned
# 0           464
# 1           456
# 2           377

# %%
sns.barplot(x="IsActiveMember", y="Exited", data=df)
# Out:
# <Axes: xlabel='IsActiveMember', ylabel='Exited'>

# %%
df.groupby("IsActiveMember")["Exited"].mean()
# Out:
# IsActiveMember
# 0    0.268715
# 1    0.142691
# Name: Exited, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))

sns.regplot(x="Age", y="Exited", data=df, ax=ax1, color="green")
ax1.set_title("Age vs Exited in Regplot")

sns.violinplot(x="NumOfProducts", y="Exited", data=df, ax=ax2)
ax2.set_title("NumOfProducts vs Exited in Violinplot")

plt.tight_layout()
plt.show()

# %%
df.groupby("NumOfProducts")["Exited"].agg(["mean", "count"])
# Out:
#                    mean  count
# NumOfProducts
# 1              0.277144   5084
# 2              0.076035   4590
# 3              0.827068    266
# 4              1.000000     60

# %%
df.sample(3)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 4029       4030    15634218   Mancini          501   Germany    Male   27
# 2812       2813    15581620  Franklin          597    France    Male   28
# 2712       2713    15628170     Brown          565   Germany  Female   32
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4029       4  95331.83              2          1               0
# 2812       2      0.00              3          1               1
# 2712       9  68067.24              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 4029        132104.76       0         0                   1   DIAMOND
# 2812         78707.97       0         0                   3    SILVER
# 2712        143287.58       0         0                   3    SILVER
#
#       Point Earned
# 4029           301
# 2812           793
# 2712           504

# %%
sns.jointplot(x="CreditScore", y="Exited", data=df, color="yellow", edgecolor="red", hue="Gender", kind="kde")
# Out:
# C:\Users\OsiyoComputers\anaconda\Lib\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'edgecolor'
#   cset = contour_func(

# %%
df.groupby("Exited")["CreditScore"].mean()
# Out:
# Exited
# 0    651.837855
# 1    645.414622
# Name: CreditScore, dtype: float64

# %%
df.groupby("Gender")["Exited"].agg(["mean", "count"])
# Out:
#             mean  count
# Gender
# Female  0.250715   4543
# Male    0.164743   5457

# %%
# sns.swarmplot(x="Tenure", y="Exited", data=df)

# %%
sns.barplot(x="Tenure", y="Exited", data=df, hue="Geography")
# Out:
# <Axes: xlabel='Tenure', ylabel='Exited'>

# %%
df.groupby("Tenure")["Exited"].mean()
# Out:
# Tenure
# 0     0.230024
# 1     0.224155
# 2     0.191794
# 3     0.211100
# 4     0.205258
# 5     0.206522
# 6     0.202689
# 7     0.172179
# 8     0.192195
# 9     0.217480
# 10    0.206122
# Name: Exited, dtype: float64

# %%
sns.barplot(x="NumOfProducts", y="Exited", data=df, hue="IsActiveMember")
# Out:
# <Axes: xlabel='NumOfProducts', ylabel='Exited'>

# %%
df.sample(3)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 585         586    15718057  Onyinyechukwuka          760    France  Female
# 2539       2540    15569571         Davydova          584   Germany  Female
# 3170       3171    15791373         Chikezie          850   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 585    51       2  100946.71              1          0               0
# 2539   46       6   87361.02              2          1               0
# 3170   35       2   80931.75              1          0               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 585         179614.80       1         1                   4   DIAMOND
# 2539        120376.87       1         1                   4  PLATINUM
# 3170         12639.67       1         1                   2   DIAMOND
#
#       Point Earned
# 585            550
# 2539           400
# 3170           983

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))

sns.kdeplot(x="Balance", hue="Exited",data=df, ax=ax1)
ax1.set_title("Balance by hue Exited")

sns.boxplot(x="EstimatedSalary", hue="Exited", data=df, ax=ax2)
ax2.set_title("EstimatedSalary vs Exited")

plt.tight_layout()
plt.show()

# %%
df.groupby("Exited")["EstimatedSalary"].mean()
# Out:
# Exited
# 0     99726.853141
# 1    101509.908783
# Name: EstimatedSalary, dtype: float64

# %%
sns.violinplot(x="HasCrCard", hue="Exited", data=df)
# Out:
# <Axes: xlabel='HasCrCard'>

# %%
df.groupby("HasCrCard")["Exited"].mean()
# Out:
# HasCrCard
# 0    0.208149
# 1    0.201984
# Name: Exited, dtype: float64

# %%
df["HasZeroBalance"] = (df["Balance"] == 0).astype(int)
df.groupby("HasZeroBalance")["Exited"].agg(["mean", "count"])
# Out:
#                     mean  count
# HasZeroBalance
# 0               0.240953   6383
# 1               0.138236   3617

# %%
sns.countplot(x="Card Type", data=df, hue="Exited")
# Out:
# <Axes: xlabel='Card Type', ylabel='count'>

# %%
df.groupby("Card Type")["Exited"].mean()
# Out:
# Card Type
# DIAMOND     0.217790
# GOLD        0.192646
# PLATINUM    0.203607
# SILVER      0.201122
# Name: Exited, dtype: float64

# %%
sns.boxplot(x="Satisfaction Score", hue="Exited", data=df)
# Out:
# <Axes: xlabel='Satisfaction Score'>

# %%
df.groupby("Satisfaction Score")["Exited"].mean()
# Out:
# Satisfaction Score
# 1    0.200311
# 2    0.217974
# 3    0.196376
# 4    0.206175
# 5    0.198104
# Name: Exited, dtype: float64

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))

sns.kdeplot(x="Point Earned", hue="Exited", data=df, ax=ax1, color="green")
ax1.set_title("Kdeplot")

sns.boxplot(x="Point Earned", hue="Exited", data=df, ax=ax2, color="red")
ax2.set_title("Boxplot")

plt.show()
# Out:
# C:\Users\OsiyoComputers\AppData\Local\Temp\ipykernel_8356\2133548544.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.boxplot(x="Point Earned", hue="Exited", data=df, ax=ax2, color="red")

# %%
df.groupby("Exited")["Point Earned"].mean()
# Out:
# Exited
# 0    607.044084
# 1    604.448479
# Name: Point Earned, dtype: float64

# %%
df.groupby("Exited")["Complain"].mean()
# Out:
# Exited
# 0    0.001256
# 1    0.998037
# Name: Complain, dtype: float64

# %%
df.sample(5)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 1443       1444    15598751           Ingram          556    France  Female
# 8128       8129    15682928  Chiazagomekpere          695     Spain    Male
# 1998       1999    15779497            Ts'ai          603    France    Male
# 3010       3011    15619653        Hannaford          666    France    Male
# 3277       3278    15749381               Yu          790    France  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1443   43       6       0.00              3          0               0
# 8128   39       4   65521.20              1          1               1
# 1998   43       5  127823.93              1          1               1
# 3010   47       2       0.00              1          1               0
# 3277   41       2  126619.27              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 1443        125154.57       1         1                   4      GOLD
# 8128          1243.97       0         0                   5  PLATINUM
# 1998         19483.35       0         0                   1    SILVER
# 3010         35046.97       1         1                   4      GOLD
# 3277        198224.38       0         0                   4   DIAMOND
#
#       Point Earned  HasZeroBalance
# 1443           877               1
# 8128           494               0
# 1998           711               0
# 3010           354               1
# 3277           696               0

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature engineering

# %%
df.sample(5)
# Out:
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 2910       2911    15746139         Enemuo          596    France    Male
# 8097       8098    15706557       Ferguson          626    France  Female
# 9205       9206    15758750  Iweobiegbunam          564    France    Male
# 6277       6278    15697391         Argyle          604     Spain  Female
# 7438       7439    15676156          Boyle          528    France  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2910   33       2  139451.67              1          0               0
# 8097   52       0       0.00              2          1               0
# 9205   31       0  110527.17              1          1               1
# 6277   34       3       0.00              2          1               0
# 7438   32       4   85615.66              2          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 2910         63142.12       0         0                   4  PLATINUM
# 8097         32159.46       1         1                   3    SILVER
# 9205         87060.77       0         0                   2      GOLD
# 6277         38587.70       0         0                   1   DIAMOND
# 7438        156192.43       0         0                   2    SILVER
#
#       Point Earned  HasZeroBalance
# 2910           640               0
# 8097           959               1
# 9205           752               0
# 6277           407               1
# 7438           518               0

# %%
# Dropping unnecessary cols - RowNumber, CustomerId, Surname as they are not be needed for model performance
# df = df.drop(columns=["RowNumber", "CustomerId"])
# df = df.drop(columns=["Surname"])

# %%
df.sample(3)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 4822          745    France  Female   32       2       0.00              4
# 9884          751    France  Female   48       4       0.00              1
# 2004          684   Germany    Male   29       8  127269.75              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 4822          0               1        179705.13       1         1
# 9884          0               1         30165.06       1         1
# 2004          0               1         79495.01       0         0
#
#       Satisfaction Score Card Type  Point Earned  HasZeroBalance
# 4822                   3  PLATINUM           467               1
# 9884                   3   DIAMOND           591               1
# 2004                   4  PLATINUM           742               0

# %%
# Removdf = df.drop(columns=["Surname"])ing compain is the best choice as it affects negatively to the model performanca since more that 99% of users who did compain churned.
df = df.drop(columns=["Complain"])

# %%
df.sample(3)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 4581          572    France  Female   47       2       0.00              2
# 9715          680     Spain  Female   34       7       0.00              2
# 6099          532   Germany    Male   52       9  137755.76              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Satisfaction Score  \
# 4581          1               0         36099.70       0                   4
# 9715          1               0         98949.85       0                   5
# 6099          1               0        163191.99       1                   2
#
#      Card Type  Point Earned  HasZeroBalance
# 4581      GOLD           991               1
# 9715  PLATINUM           912               1
# 6099      GOLD           401               0

# %%
df.columns.to_list()
# Out:
# ['CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited',
#  'Satisfaction Score',
#  'Card Type',
#  'Point Earned',
#  'HasZeroBalance']

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# i will drop has zero balance i did just added it for better understanding
df = df.drop(columns=["HasZeroBalance"])

# %%
df.sample(4)
# Out:
#       CreditScore Geography Gender  Age  Tenure    Balance  NumOfProducts  \
# 1943          728   Germany   Male   39       6  152182.83              1
# 3452          757    France   Male   57       3   89079.41              1
# 9294          713    France   Male   36       8  133889.35              1
# 5874          597    France   Male   19       2       0.00              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Satisfaction Score  \
# 1943          0               0        161203.60       0                   4
# 3452          1               1         53179.21       1                   4
# 9294          1               1        143265.65       0                   1
# 5874          1               1         91036.74       0                   3
#
#      Card Type  Point Earned
# 1943   DIAMOND           256
# 3452   DIAMOND           789
# 9294    SILVER           357
# 5874      GOLD           270

# %%
# And now it is time to move to encoding part: categorical to numerical
# geography, gender, card type

# %%
df["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df[ "Card Type"].unique()
# Out:
# array(['DIAMOND', 'GOLD', 'SILVER', 'PLATINUM'], dtype=object)

# %%
# one-hot encoding geography
# df = pd.get_dummies(df, columns=["Geography"], drop_first=True, dtype=int)
df.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619  Female   42       2       0.00              1          1
# 1          608  Female   41       1   83807.86              1          0
# 2          502  Female   42       8  159660.80              3          1
# 3          699  Female   39       1       0.00              2          0
# 4          850  Female   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Satisfaction Score Card Type  \
# 0               1        101348.88       1                   2   DIAMOND
# 1               1        112542.58       0                   3   DIAMOND
# 2               0        113931.57       1                   3   DIAMOND
# 3               0         93826.63       0                   5      GOLD
# 4               1         79084.10       0                   5      GOLD
#
#    Point Earned  Geography_Germany  Geography_Spain
# 0           464                  0                0
# 1           456                  0                1
# 2           377                  0                0
# 3           350                  0                0
# 4           425                  0                1

# %%
# binary encoding gender 
# df["Gender"] = df["Gender"].map({"Female": 0, "Male": 1})

# %%
# # Ordinal encode Card Type
# df["Card Type"] = df["Card Type"].map({
#     "SILVER": 0,
#     "GOLD": 1,
#     "PLATINUM": 2,
#     "DIAMOND": 3
# })

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CreditScore         10000 non-null  int64
#  1   Gender              10000 non-null  int64
#  2   Age                 10000 non-null  int64
#  3   Tenure              10000 non-null  int64
#  4   Balance             10000 non-null  float64
#  5   NumOfProducts       10000 non-null  int64
#  6   HasCrCard           10000 non-null  int64
#  7   IsActiveMember      10000 non-null  int64
#  8   EstimatedSalary     10000 non-null  float64
#  9   Exited              10000 non-null  int64
#  10  Satisfaction Score  10000 non-null  int64
#  11  Card Type           10000 non-null  int64
#  12  Point Earned        10000 non-null  int64
#  13  Geography_Germany   10000 non-null  int64
#  14  Geography_Spain     10000 non-null  int64
# dtypes: float64(2), int64(13)
# memory usage: 1.1 MB

# %%
df.sample(5)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6387          513       0   43       9       0.00              2          1
# 3543          675       1   49       8  135133.39              1          0
# 1229          575       0   31       6       0.00              2          1
# 1356          709       1   49       4  154344.49              2          1
# 2580          697       0   38       6  132591.36              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Satisfaction Score  Card Type  \
# 6387               0        152499.80       0                   1          0
# 3543               1        179521.24       1                   4          1
# 1229               1         95686.42       0                   4          0
# 1356               1         38794.57       0                   2          3
# 2580               1          7387.80       1                   3          3
#
#       Point Earned  Geography_Germany  Geography_Spain
# 6387           301                  0                0
# 3543           229                  0                0
# 1229           609                  0                1
# 1356           330                  0                0
# 2580           322                  1                0

# %%
print(df["Gender"].unique())
print(df["Card Type"].unique())
# Out:
# [0 1]
# [3 1 0 2]

# %% [markdown]
# # Modelling
